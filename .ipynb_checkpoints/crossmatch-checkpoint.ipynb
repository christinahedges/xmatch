# %%
from astropy.io import fits
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import astropy.units as u
# %matplotlib inline

# %%
h=fits.open('C02_master_merged.fits')
mag=25-2.5*np.log10(h[1].data['Total_flux'])
RA,Dec=h[1].data['RA']*u.radian,h[1].data['DEC']*u.radian
RA,Dec=RA.to(u.deg),Dec.to(u.deg)

#Ensure all targets are unique
unq=np.unique(RA*Dec,return_index=True)[1]
RA,Dec,mag=RA[unq],Dec[unq],mag[unq]

# %%
targs=pd.read_csv('K2Campaign2targets.csv')
t_ids,t_RA,t_Dec,t_mag=np.zeros(len(targs),dtype=int),np.zeros(len(targs)),np.zeros(len(targs)),np.zeros(len(targs))
for i,ID,r,d,m in zip(xrange(len(targs)),targs[targs.keys()[0]],targs[targs.keys()[1]],targs[targs.keys()[2]],targs[targs.keys()[3]]):
    try: 
        t_ids[i]=ID
        t_RA[i]=float(r)
        t_Dec[i]=float(d)
        t_mag[i]=float(m)
    except:
        continue
ok=np.any([[t_RA!=0],[t_Dec!=0],[t_mag!=0]],axis=0)[0]
t_RA=t_RA[ok]
t_Dec=t_Dec[ok]
t_mag=t_mag[ok]
t_ids=t_ids[ok]
#Ensure all targets are unique
unq=np.unique(t_RA*t_Dec,return_index=True)[1]
t_RA,t_Dec,t_mag,t_ids=t_RA[unq],t_Dec[unq],t_mag[unq],t_ids[unq]
t_ids=np.asarray(t_ids,dtype=str)

# %%
t_ids
# Out:
# array([202625828, 202642998, 202643314, ..., 205739705, 205743394,
#        205743799])

# %%
plt.figure(figsize=(9,8))
plt.scatter(RA,Dec,c=mag,s=0.1,vmin=5,vmax=20)
cbar=plt.colorbar()
plt.xlabel('RA')
plt.ylabel('Dec')
cbar.set_label('Magnitude')
plt.title('Campaign 2 (K2SC Target List)')
plt.savefig('images/radec.png',dpi=150,bbox_inches='tight')

# %%
plt.figure(figsize=(9,8))
plt.scatter(t_RA,t_Dec,c=t_mag,s=0.1,vmin=5,vmax=20)
cbar=plt.colorbar()
plt.xlabel('RA')
plt.ylabel('Dec')
cbar.set_label('Magnitude')
plt.title('Campaign 2 (Original Target List)')
plt.savefig('images/radec2.png',dpi=150,bbox_inches='tight')

# %%
_=plt.hist(t_mag,60,alpha=0.4,label='Input Target List')
_=plt.hist(mag,60,alpha=0.4,label='K2SC Target List')
plt.yscale('log')
plt.ylabel('Frequency')
plt.xlabel('Magnitude')
plt.legend()
plt.savefig('images/histogram.png',dpi=150,bbox_inches='tight')

# %%
from astropy.coordinates import SkyCoord
crossmatch_tolerance=1*u.arcsec #One pixel. This is still quite large

K2SCcatalog = SkyCoord(ra=RA, dec=Dec)
targcatalog = SkyCoord(ra=t_RA*u.deg,dec=t_Dec*u.deg)
idx, d2d, d3d = targcatalog.match_to_catalog_sky(K2SCcatalog) 
K2SCpos=idx[d2d<=crossmatch_tolerance]
idx2, d2d2, d3d2 = K2SCcatalog[K2SCpos].match_to_catalog_sky(targcatalog)  
targpos=idx2[d2d2<=crossmatch_tolerance]

# %%
fig,ax=plt.subplots()
_=ax.hist(np.log10(d2d.to(u.arcsec).value),200)
plt.yscale('log')
plt.axvline(np.log10(crossmatch_tolerance.value),c='C1',lw=3)
plt.ylabel('Frequency')
plt.xlabel('log10(Separation) (arcseconds)')
plt.title('Cross Match Separation')
plt.text(np.log10(crossmatch_tolerance.value+0.5),3E2,"{}".format(crossmatch_tolerance.value)+'"',rotation=270,color='C1')
plt.savefig('images/crossmatch.png',dpi=150,bbox_inches='tight')

# %%
plt.figure(figsize=(9.5,8))
plt.scatter(RA[K2SCpos],Dec[K2SCpos],c=t_mag[targpos]-mag[K2SCpos],s=3)
plt.colorbar()
plt.xlabel('RA')
plt.ylabel('Dec')
cbar.set_label('Magnitude Difference')
plt.title('Campaign 2 (Original Mag - K2SC Mag at 1" Crossmatch)')
plt.savefig('images/diffradec.png',dpi=150,bbox_inches='tight')

# %%
targlist=pd.read_csv('/Users/christina/Downloads/epic_1_06jul17.txt',delimiter='|')
targlist=targlist[(np.asarray(targlist.k2_ra)>=238.) & (np.asarray(targlist.k2_ra)<=255.) & 
                  (np.asarray(targlist.k2_dec)>=-30.) & (np.asarray(targlist.k2_dec)<=-15)]
targlist=targlist.reset_index(drop=True)

# %%
plt.plot(targlist.kp,marker='.',ms=0.1,ls='')
print np.asarray(targlist.kp)[6E6:6001E6]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-269db31e923a> in <module>()
#       1 plt.plot(targlist.kp,marker='.',ms=0.1,ls='')
# ----> 2 print np.asarray(targlist.kp)[6E6:6001E6]
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %%
plt.scatter(targlist.k2_ra,targlist.k2_dec,s=0.1)

# %%
EPICcatalog=SkyCoord(targlist.k2_ra*u.deg,targlist.k2_dec*u.deg)
idx3, d2d3, d3d = K2SCcatalog[K2SCpos].match_to_catalog_sky(EPICcatalog)

# %%
print np.unique(targlist.kepflag[idx3])
# Out:
# [nan nan nan nan nan nan nan nan 'BV' 'J' 'JHK' 'gri']

# %%
good=np.where((targlist.kepflag[idx3]=='gri') | (targlist.kepflag[idx3]=='BV'))[0]
print float(len(good))/len(idx3)
# Out:
# 0.651678774789

# %%
_=plt.hist(targlist.kp[idx3]-mag[K2SCpos],300,normed=True)
plt.yscale('log')
plt.ylabel('Normalised Frequency')
plt.xlabel('Original Input Kp Mag - K2SC Mag')
plt.title('Magnitude Difference in Cross Matched Sample')

plt.savefig('images/mag_match1.png',dpi=150,bbox_inches='tight')

# %%
_=plt.hist(np.asarray(targlist.kp[idx3])[good]-mag[K2SCpos][good],300,normed=True)
plt.yscale('log')
plt.ylabel('Normalised Frequency')
plt.xlabel('Original Input Kp Mag - K2SC Mag with No J band Kp Mags')
plt.title('Magnitude Difference in Cross Matched Sample')
plt.savefig('images/mag_match2.png',dpi=150,bbox_inches='tight')

# %%
diff=np.asarray(targlist.kp[idx3])[good]-mag[K2SCpos][good]
print 100.*float(len(np.where(diff<=0.5)[0]))/len(diff),'%'
# Out:
# 81.7414884001 %

# %%
idx4, d2d4, d3d = K2SCcatalog.match_to_catalog_sky(EPICcatalog)

# %%
_=plt.hist(np.asarray(targlist.kp[idx4])-mag,300,normed=True)
plt.yscale('log')
plt.ylabel('Normalised Frequency')
# 3316130  205731923  NaN          NaN  374-076633  16364745-1523074  NaN
# 3262909  205678702  NaN          NaN  371-074447  16064330-1551201  NaN
# 3288017  205703810  NaN          NaN  372-075011  16195506-1538250  NaN
# 3315837  205731630  NaN          NaN  374-076556  16355254-1523174  NaN
# 3293551  205709344  NaN          NaN  373-077710  16224379-1535281  NaN
# 3311858  205727651  NaN          NaN  373-078418  16331701-1525323  NaN
# 3317608  205733401  NaN          NaN  374-076621  16363492-1522160  NaN
# 3263849  205679642  NaN   6200-380-1  371-074428  16063027-1550522  NaN
# 3264657  205680450  NaN          NaN  371-074432  16063118-1550283  NaN
# 3312376  205728169  NaN          NaN  373-078366  16323389-1525146  NaN
# 3322390  205738183  NaN          NaN  374-076743  16384607-1519298  NaN
# 3314330  205730123  NaN          NaN  373-078454  16333991-1524092  NaN
# 3270622  205686415  NaN          NaN  372-073881  16090382-1547257  NaN
# 3303596  205719389  NaN          NaN  373-077987  16270560-1530068  NaN
# 3267058  205682851  NaN          NaN  371-074449  16064410-1549156  NaN
# 3321249  205737042  NaN          NaN  374-076617  16363276-1520091  NaN
# 3322649  205738442  NaN          NaN  374-076666  16372101-1519212  NaN
# 3321561  205737354  NaN          NaN  374-076606  16362093-1519591  NaN
# 3321561  205737354  NaN          NaN  374-076606  16362093-1519591  NaN
# 3321914  205737707  NaN   6216-744-1  374-076604  16361884-1519474  NaN
# 3320262  205736055  NaN          NaN  374-076514  16351166-1520435  NaN
# 3323912  205739705  NaN          NaN  374-076677  16372849-1518363  NaN
# 3327341  205743134  NaN          NaN  374-076734  16383916-1516328  NaN
# 3327601  205743394  NaN          NaN  374-076732  16383794-1516239  NaN
# 3328006  205743799  NaN          NaN  374-076755  16385145-1516107  NaN
#
#         objtype kepflag stpropflag       k2_ra      ...              d  \
# 269697     STAR       J        NaN  251.254758      ...            NaN
# 270570     STAR     gri        NaN  251.249091      ...            NaN
# 256153     STAR     gri        rpm  250.769688      ...         229.10
# 256820     STAR     JHK        NaN  250.776159      ...            NaN
# 273323     STAR       J        rpm  251.256341      ...         461.50
# 275844     STAR     JHK        NaN  251.260735      ...            NaN
# 276314     STAR     gri        NaN  251.249887      ...            NaN
# 273639     STAR     gri        rpm  251.125409      ...         542.70
# 277898     STAR       J        NaN  251.257560      ...            NaN
# 241998     STAR     JHK        NaN  250.065311      ...            NaN
# 243087     STAR     JHK        NaN  250.060144      ...            NaN
# 242999     STAR       J        NaN  250.048853      ...            NaN
# 244483     STAR     JHK        NaN  250.052999      ...            NaN
# 214391     STAR      BV        rpm  249.058475      ...         473.60
# 244755     STAR     JHK        NaN  250.046253      ...            NaN
# 216584     STAR     JHK        NaN  249.061326      ...            NaN
# 265905     STAR     gri        rpm  250.674249      ...         380.20
# 254206     STAR      BV        NaN  250.279405      ...            NaN
# 265786     STAR     gri        rpm  250.654326      ...         715.50
# 234412     STAR     JHK        rpm  249.593326      ...         162.80
# 255296     STAR     JHK        rpm  250.272795      ...         710.10
# 267227     STAR     gri        NaN  250.658159      ...            NaN
# 247947     STAR     JHK        rpm  250.012650      ...         630.30
# 271557     STAR     JHK        rpm  250.769411      ...         143.90
# 249950     STAR      BV        NaN  250.056130      ...            NaN
# 254235     STAR     JHK        rpm  250.170388      ...         694.20
# 212895     STAR     JHK        NaN  248.790784      ...            NaN
# 213220     STAR      BV        rpm  248.798773      ...        7736.00
# 239008     STAR      BV        NaN  249.613744      ...            NaN
# 254133     STAR     JHK        NaN  250.055569      ...            NaN
# ...         ...     ...        ...         ...      ...            ...
# 3270306    STAR     gri        rpm  242.988218      ...         361.10
# 3296358    STAR     gri        rpm  246.466734      ...         170.20
# 3313565    STAR     gri        rpm  248.890602      ...         400.80
# 3276337    STAR     gri        rpm  243.625487      ...         565.80
# 3304719    STAR     gri        rpm  247.523946      ...         410.70
# 3316130    STAR     gri        rpm  249.197754      ...        2897.00
# 3262909    STAR     gri        rav  241.680459      ...        4708.00
# 3288017    STAR     gri        rpm  244.979460      ...         527.90
# 3315837    STAR     JHK        rpm  248.968946      ...          46.97
# 3293551    STAR     gri        rpm  245.682457      ...         126.30
# 3311858    STAR     JHK        rpm  248.320940      ...         177.90
# 3317608    STAR     gri        NaN  249.145530      ...            NaN
# 3263849    STAR     gri        rpm  241.626238      ...         362.60
# 3264657    STAR     gri        NaN  241.629894      ...            NaN
# 3312376    STAR     gri        rpm  248.141253      ...         638.70
# 3322390    STAR     JHK        rpm  249.691966      ...        8602.00
# 3314330    STAR     gri        NaN  248.416344      ...            NaN
# 3270622    STAR     gri        rav  242.265947      ...         154.80
# 3303596    STAR     gri        rpm  246.773326      ...          91.64
# 3267058    STAR     gri        rav  241.683779      ...        1248.00
# 3321249    STAR     JHK        rpm  249.136534      ...        9247.00
# 3322649    STAR     gri        rpm  249.337569      ...          99.20
# 3321561    STAR     JHK        NaN  249.087228      ...            NaN
# 3321561    STAR     JHK        NaN  249.087228      ...            NaN
# 3321914    STAR     gri        rpm  249.078579      ...         287.20
# 3320262    STAR     JHK        rpm  248.798477      ...         256.50
# 3323912    STAR     gri        rpm  249.368673      ...        8952.00
# 3327341    STAR     gri        NaN  249.663177      ...            NaN
# 3327601    STAR     JHK        rpm  249.658109      ...        5884.00
# 3328006    STAR     JHK        rpm  249.714325      ...         171.80
#
#             ep_d      em_d     ebv  ep_ebv  em_ebv  nomad  \
# 269697       NaN       NaN     NaN     NaN     NaN    NaN
# 270570       NaN       NaN     NaN     NaN     NaN    NaN
# 256153     96.02    67.660  0.1752  0.1088  0.0680    NaN
# 256820       NaN       NaN     NaN     NaN     NaN    NaN
# 273323   4870.00    87.110  4.7760  0.0010  4.3608    NaN
# 275844       NaN       NaN     NaN     NaN     NaN    NaN
# 276314       NaN       NaN     NaN     NaN     NaN    NaN
# 273639    189.70   104.600  0.2503  0.1480  0.0888    NaN
# 277898       NaN       NaN     NaN     NaN     NaN    NaN
# 241998       NaN       NaN     NaN     NaN     NaN    NaN
# 243087       NaN       NaN     NaN     NaN     NaN    NaN
# 242999       NaN       NaN     NaN     NaN     NaN    NaN
# 244483       NaN       NaN     NaN     NaN     NaN    NaN
# 214391    113.90   197.300  0.3464  0.2592  0.1620    NaN
# 244755       NaN       NaN     NaN     NaN     NaN    NaN
# 216584       NaN       NaN     NaN     NaN     NaN    NaN
# 265905     99.32    51.340  0.2510  0.1498  0.1070    NaN
# 254206       NaN       NaN     NaN     NaN     NaN    NaN
# 265786    207.10   247.100  0.4108  0.1668  0.1390    NaN
# 234412     64.93    32.640  0.2571  0.1090  0.1308    NaN
# 255296    236.80   235.500  0.3185  0.2088  0.1160    NaN
# 267227       NaN       NaN     NaN     NaN     NaN    NaN
# 247947    249.80   208.100  0.3579  0.2176  0.1632    NaN
# 271557    201.70    47.270  0.2236  0.5502  0.1310    NaN
# 249950       NaN       NaN     NaN     NaN     NaN    NaN
# 254235    399.40   192.400  0.3011  0.1984  0.1240    NaN
# 212895       NaN       NaN     NaN     NaN     NaN    NaN
# 213220   2439.00  3264.000  0.3789  0.2794  0.1270    NaN
# 239008       NaN       NaN     NaN     NaN     NaN    NaN
# 254133       NaN       NaN     NaN     NaN     NaN    NaN
# ...          ...       ...     ...     ...     ...    ...
# 3270306   107.90    54.450  0.2514  0.1050  0.0900    NaN
# 3296358  1218.00     5.107  0.5375  0.6720  0.0024    NaN
# 3313565   209.20   137.500  0.6015  0.0580  0.1740    NaN
# 3276337   158.40    80.890  0.2305  0.0994  0.0852    NaN
# 3304719   186.20   112.600  0.5839  0.2260  0.2260    NaN
# 3316130  3243.00  1375.000  1.2061  0.1464  0.2196    NaN
# 3262909   648.00   674.900  0.3412  0.4068  0.1130    NaN
# 3288017    91.76   112.800  1.7315  0.1688  0.0032    NaN
# 3315837    29.14    10.070  0.0539  0.0480  0.0150    NaN
# 3293551    26.96    22.220  0.1209  0.1440  0.0600    NaN
# 3311858    62.09    46.030  0.1588  0.1728  0.0720    NaN
# 3317608      NaN       NaN     NaN     NaN     NaN    NaN
# 3263849   148.40   122.400  0.3435  0.1040  0.1248    NaN
# 3264657      NaN       NaN     NaN     NaN     NaN    NaN
# 3312376   222.10   164.800  0.6847  0.1356  0.1356    NaN
# 3322390  2103.00  3514.000  0.7045  0.4312  0.3080    NaN
# 3314330      NaN       NaN     NaN     NaN     NaN    NaN
# 3270622    23.26    15.430  0.1310  0.1360  0.0408    NaN
# 3303596    18.28    20.600  0.0934  0.1020  0.0408    NaN
# 3267058   104.70   168.500  0.3402  0.2912  0.1120    NaN
# 3321249  2416.00  1413.000  0.5932  0.3108  0.2590    NaN
# 3322649    44.85     2.976  0.0634  0.0550  0.0110    NaN
# 3321561      NaN       NaN     NaN     NaN     NaN    NaN
# 3321561      NaN       NaN     NaN     NaN     NaN    NaN
# 3321914   131.60    38.440  0.5790  0.1812  0.1812    NaN
# 3320262    84.78    74.420  0.5596  1.0224  0.2840    NaN
# 3323912   693.40  1144.000  0.4469  0.0868  0.1364    NaN
# 3327341      NaN       NaN     NaN     NaN     NaN    NaN
# 3327601  3859.00  3258.000  0.6314  0.3360  0.2800    NaN
# 3328006   407.70    62.910  0.1456  0.6432  0.0804    NaN
#
#                         mflg       prox  k2_avail_flag
# 269697   AUU-266-200-c00-0-0   4.200000              0
